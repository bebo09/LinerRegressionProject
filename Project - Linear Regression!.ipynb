# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame, 

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
# %matplotlib inline

# %%
loans_data = pd.read_csv('https://spark-public.s3.amazonaws.com/dataanalysis/loansData.csv')
loans_data.head()
# Out:
#        Amount.Requested  Amount.Funded.By.Investors Interest.Rate Loan.Length  \
# 81174             20000                     20000.0         8.90%   36 months
# 99592             19200                     19200.0        12.12%   36 months
# 80059             35000                     35000.0        21.98%   60 months
# 15825             10000                      9975.0         9.99%   36 months
# 33182             12000                     12000.0        11.71%   36 months
#
#              Loan.Purpose Debt.To.Income.Ratio State Home.Ownership  \
# 81174  debt_consolidation               14.90%    SC       MORTGAGE
# 99592  debt_consolidation               28.36%    TX       MORTGAGE
# 80059  debt_consolidation               23.81%    CA       MORTGAGE
# 15825  debt_consolidation               14.30%    KS       MORTGAGE
# 33182         credit_card               18.78%    NJ           RENT
#
#        Monthly.Income FICO.Range  Open.CREDIT.Lines  Revolving.CREDIT.Balance  \
# ...

# %%
loans_data['Loan.Length'][0:10]
# Out:
# 81174    36 months
# 99592    36 months
# 80059    60 months
# 15825    36 months
# 33182    36 months
# 62403    36 months
# 48808    36 months
# 22090    60 months
# 76404    36 months
# 15867    36 months
# Name: Loan.Length, dtype: object

# %%
loans_data['Interest.Rate'][0:10]
# Out:
# 81174     8.90%
# 99592    12.12%
# 80059    21.98%
# 15825     9.99%
# 33182    11.71%
# 62403    15.31%
# 48808     7.90%
# 22090    17.14%
# 76404    14.33%
# 15867     6.91%
# Name: Interest.Rate, dtype: object

# %%
loans_data['FICO.Range'][0:10]
# Out:
# 81174    735-739
# 99592    715-719
# 80059    690-694
# 15825    695-699
# 33182    695-699
# 62403    670-674
# 48808    720-724
# 22090    705-709
# 76404    685-689
# 15867    715-719
# Name: FICO.Range, dtype: object

# %%
# "715-719"(715, 719) ## WE NEED TO CONVERT THE FICO SCORES INTO STRINGS THEN PARSE THEM

# %%
loans = pd.read_csv('loan.csv') ## clean data
loans.head()
# Out:
#     Interest.Rate  FICO.Score  Loan.Length  Monthly.Income  Loan.Amount
# 6           15.31         670           36         4891.67         6000
# 11          19.72         670           36         3575.00         2000
# 12          14.27         665           36         4250.00        10625
# 13          21.67         670           60        14166.67        28000
# 21          21.98         665           36         6666.67        22000

# %%
# after data has been cleaned now is time for visiualiing the data

plt.figure()

loans = pd.read_csv('loan.csv')
fico = loans['FICO.Score']
fico.hist(bins = 20)

# %%
plt.figure()   # creating a BOX Plot

loans = pd.read_csv('loan.csv')

x = loans.boxplot('Interest.Rate', 'FICO.Score')

x.set_xticklabels(['630','','','','', '660', '','','','', '690','','','','', '720', '','','','', '750', '','','','', '780', '','','','', '810', '','','','', '840'])
x.set_xlabel("FICO Score")
x.set_ylabel("Inter Rate in %")
# set_title
# Out:
# Text(0, 0.5, 'Inter Rate in %')

# %%
# scatterplot matrix - great way to look at different factors at the same time

loans = pd.read_csv('loan.csv')

pd.plotting.scatter_matrix(loans, alpha = 0.9,color = 'red', figsize = (20,20), diagonal = 'hist')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f86a1f2ecf8>,
# ...
#       dtype=object)
